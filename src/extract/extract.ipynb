# %% [markdown]
# # Import Libraries

# %%
import pandas as pd

# %% [markdown]
# # Extract Source Data

# %%
# Extract data from a all Excel files
business_services_vertical_df = pd.read_excel("/Users/ankur/Documents/GitHub/data-migration-assessment/data/source/Business Services Pipeline.xlsx", skiprows=5)
consumer_retail_and_healthcare_vertical_df = pd.read_excel("/Users/ankur/Documents/GitHub/data-migration-assessment/data/source/Consumer Retail and Healthcare Pipeline.xlsx",skiprows=8).drop(columns=['Unnamed: 0'])
contacts_df1 = pd.read_excel("/Users/ankur/Documents/GitHub/data-migration-assessment/data/source/Contacts.xlsx", sheet_name="Tier 1's")
contacts_df2 = pd.read_excel("/Users/ankur/Documents/GitHub/data-migration-assessment/data/source/Contacts.xlsx", sheet_name="Tier 2's")
events_df1 = pd.read_excel("/Users/ankur/Documents/GitHub/data-migration-assessment/data/source/Events.xlsx",sheet_name="Leaders and Partners Dinner")
events_df2 = pd.read_excel("/Users/ankur/Documents/GitHub/data-migration-assessment/data/source/Events.xlsx",sheet_name="2019 Market Re-Cap")
private_equity_companies_df = pd.read_excel("/Users/ankur/Documents/GitHub/data-migration-assessment/data/source/PE Comps.xlsx",skiprows=2)

# %% [markdown]
# # Initial Data Cleansing

# %%
# Cleansing the business services vertical DataFrame to add a new column
business_services_vertical_df['VerticalDepartment'] = "Business Services"
bs_vertical_cleansed_df = business_services_vertical_df

# Removed NULL rows from the consumer retail and healthcare vertical DataFrame
consumer_retail_and_healthcare_vertical_df = consumer_retail_and_healthcare_vertical_df[consumer_retail_and_healthcare_vertical_df['Company Name'].notna() & consumer_retail_and_healthcare_vertical_df['Lead MD'].notna()]

#Add a new column to the cleansed DataFrame
consumer_retail_and_healthcare_vertical_df['VerticalDepartment'] = "Consumer Retail and Healthcare"
crh_vertical_cleansed_df = consumer_retail_and_healthcare_vertical_df

# Concatenate the contacts DataFrames
contacts_cleansed_df = pd.concat([contacts_df1, contacts_df2], ignore_index=True)

# Set the 'EventType' for each event DataFrame
events_df1['EventType'] = 'Leaders and Partners Dinner'
events_df2['EventType'] = '2019 Market Re-Cap'

# Concatenate the events DataFrames
events_cleansed_df = pd.concat([events_df1, events_df2], ignore_index=True)

# Cleansing the private equity companies DataFrame
private_equity_companies_cleansed_df = private_equity_companies_df.copy()

# %%
# Concatenate the cleansed vertical DataFrames
all_vertical_deals_df = pd.concat([bs_vertical_cleansed_df, crh_vertical_cleansed_df], ignore_index=True)

# %% [markdown]
# # Display Extracted Data

# %%
all_vertical_deals_df.head()  # Display the first few rows of the concatenated DataFrame
# Out:
#      Company Name Project Name           Date Added      Invest. Bank Banker  \
# 0         Shermco          NaN  2018-02-02 00:00:00   Harris Williams    NaN
# 1  Kastle Systems          NaN  2018-02-02 00:00:00               NaN    NaN
# 2      CLEAResult          NaN  2018-02-02 00:00:00               NaN    NaN
# 3             PLH          NaN  2018-02-02 00:00:00          Barclays    NaN
# 4  BBB Industries          NaN  2018-02-02 00:00:00  Baird, Jefferies    NaN
#
#          Sourcing    Transaction Type  LTM Revenue  LTM EBITDA 2014A EBITDA  \
# 0         Auction  Sponsor to Sponsor          NaN         NaN          NaN
# 1  Trusted Netwok  Sponsor to Sponsor          NaN         NaN          NaN
# 2  Trusted Netwok  Sponsor to Sponsor          NaN         NaN          NaN
# 3         Auction  Sponsor to Sponsor          NaN         NaN          NaN
# 4         Auction  Sponsor to Sponsor          NaN         NaN          NaN
#
#    ...            Current Owner  \
# ...

# %%
contacts_cleansed_df.head()  # Display the first few rows of the contacts DataFrame
# Out:
#               Firm              Name              Title              Group  \
# 0  Harris Williams  Robert Baltimore  Managing Director  Business Services
# 1  Harris Williams       Brian Lucas  Managing Director  Business Services
# 2  Harris Williams       Luke Semple  Managing Director  Business Services
# 3  Harris Williams      Drew Spitzer  Managing Director  Business Services
# 4  Harris Williams       Derek Lewis  Managing Director  Business Services
#
#         Sub-Vertical                         E-mail           Phone  \
# 0  Business Services  BBaltimore@harriswilliams.com  (804) 648-0072
# 1  Business Services      blucas@harriswilliams.com  (804) 648-0072
# 2  Business Services     lsemple@harriswilliams.com  (804) 648-0072
# 3  Business Services    aspitzer@harriswilliams.com  (804) 648-0072
# 4  Business Services      dlewis@harriswilliams.com  (804) 648-0072
#
#   Secondary Phone          City   Birthday Coverage Person  \
# ...

# %%
events_cleansed_df.head()  # Display the first few rows of the events DataFrame
# Out:
#              Name                         E-mail Attendee Status  \
# 0   Rob Baltimore  BBaltimore@harriswilliams.com          RSVP'd
# 1     Brian Lucas      blucas@harriswilliams.com        Declined
# 2     Luke Semple     lsemple@harriswilliams.com      Checked In
# 3  Andrew Spitzer    aspitzer@harriswilliams.com         No Show
# 4     Derek Lewis      dlewis@harriswilliams.com        Declined
#
#                      EventType
# 0  Leaders and Partners Dinner
# 1  Leaders and Partners Dinner
# 2  Leaders and Partners Dinner
# 3  Leaders and Partners Dinner
# 4  Leaders and Partners Dinner

# %%
private_equity_companies_cleansed_df.head()  # Display the first few rows of the private equity companies DataFrame
# Out:
#    Priority             Company Name                     Website  AUM\n(Bns)  \
# 0       NaN                      NaN                         NaN         NaN
# 1       NaN         AEA Investors LP        www.aeainvestors.com        10.0
# 2       NaN     Audax Private Equity  www.audaxprivateequity.com        11.5
# 3       NaN             CCMP Capital         www.ccmpcapital.com        12.0
# 4       NaN  Clayton Dubilier & Rice             www.cdr-inc.com        18.0
#
#                              Sectors  \
# 0                                NaN
# 1  - Consumer products\n- Industrial
# 2                       - Industrial
# 3  - Consumer products\n- Industrial
# 4  - Consumer products\n- Industrial
#
#                         Sample Portfolio Companies  \
# 0                                              NaN
# 1         - Traeger (Current)\n- Barnet (Cosmetic)
# 2                       - Chem Specialty Chemicals
# 3          - Jetro Cash & Carry\n- Shoes for Crews
# ...

# %% [markdown]
# # Export Data into a Raw Folder

# %%
# Export Data into a raw folder
all_vertical_deals_df.to_csv('/Users/ankur/Documents/GitHub/data-migration-assessment/data/raw/all_vertical_deals.csv', index=False)
contacts_cleansed_df.to_csv('/Users/ankur/Documents/GitHub/data-migration-assessment/data/raw/contacts.csv', index=False)
events_cleansed_df.to_csv('/Users/ankur/Documents/GitHub/data-migration-assessment/data/raw/events.csv', index=False)
private_equity_companies_cleansed_df.to_csv('/Users/ankur/Documents/GitHub/data-migration-assessment/data/raw/private_equity_companies.csv', index=False)
