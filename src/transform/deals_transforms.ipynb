# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Importind DataFrames

# %%
# %store -r all_verticals_deals_df

# %% [markdown]
# # Mapping to 'Deals' Target Data Model

# %%
# Define the Deals columns
columns = [
    "Id",
    "DealName",
    "CompanyId",
    "DealDate",
    "InvestmentBankId",
    "SourcingId",
    "TransactionTypeId",
    "EstimateEquityInvestment",
    "SaleDate",
    "SalePrice",
    "SaleType",
    "BuyingSponserId",
    "SellingSponserId",
    "StatusId",
    "PortfolioCompanyStatus",
    "ActiveStagesId",
    "PassedRationale",
    "DealLeadId",
    "AdditionalDescription",
    "CreatedAt",
    "CreatedBy",
    "UpdatedAt",
    "UpdatedBy",
    "File"
]

# Create an empty DataFrame with the columns
deals_df = pd.DataFrame(columns=columns)

# %%
# Populate the Contacts DataFrame with Contact Information
transform_deals_df = pd.DataFrame()

transform_deals_df['DealName'] = all_verticals_deals_df['Project Name']
transform_deals_df['CompanyId'] = all_verticals_deals_df['Company Name']
transform_deals_df['DealDate'] = all_verticals_deals_df['Date Added']
transform_deals_df['SourcingId'] = all_verticals_deals_df['Sourcing']
transform_deals_df['InvestmentBankId'] = all_verticals_deals_df['Invest. Bank']
transform_deals_df['TransactionTypeId'] = all_verticals_deals_df['Transaction Type']
transform_deals_df['EstimateEquityInvestment'] = all_verticals_deals_df['Equity Investment Est.']
transform_deals_df['StatusId'] = all_verticals_deals_df['Status']
transform_deals_df['PortfolioCompanyStatus'] = all_verticals_deals_df['Portfolio Company Status']
transform_deals_df['ActiveStagesId'] = all_verticals_deals_df['Active Stage']
transform_deals_df['PassedRationale'] = all_verticals_deals_df['Passed Rationale']
transform_deals_df['DealLeadId'] = all_verticals_deals_df['Lead MD']
transform_deals_df['AdditionalDescription'] = all_verticals_deals_df['Business Description']
transform_deals_df['File'] = "all_verticals_deals_df"

# %%
transform_deals_df
# Out:
#      DealName                 CompanyId             DealDate       SourcingId  \
# 0                               Shermco  2018-02-02 00:00:00          Auction
# 1                        Kastle Systems  2018-02-02 00:00:00   Trusted Netwok
# 2                            CLEAResult  2018-02-02 00:00:00   Trusted Netwok
# 3                                   PLH  2018-02-02 00:00:00          Auction
# 4                        BBB Industries  2018-02-02 00:00:00          Auction
# ..        ...                       ...                  ...              ...
# 314               Schweiger Dermatology  2018-01-17 00:00:00  Trusted Network
# 315                           Firebirds  2017-12-01 00:00:00
# 316                               Pacon  2017-12-01 00:00:00
# 317                     Potpourri Group  2017-12-01 00:00:00
# 318  Red Hawk  Evolution Research Group  2018-01-26 00:00:00          Auction
#
#            InvestmentBankId   TransactionTypeId EstimateEquityInvestment  \
# 0           Harris Williams  Sponsor to Sponsor                    133.5
# 1                            Sponsor to Sponsor
# 2                            Sponsor to Sponsor
# 3                  Barclays  Sponsor to Sponsor                    340.0
# 4          Baird, Jefferies  Sponsor to Sponsor                    500.0
# ..                      ...                 ...                      ...
# 314                    N/A   Sponsor to Sponsor
# 315   North Point Advisors
# 316                  Baird
# 317  Lincoln International
# 318        Harris Williams   Sponsor to Sponsor
#
#         StatusId PortfolioCompanyStatus ActiveStagesId PassedRationale  \
# 0         Active
# 1         Active
# 2         Active
# 3         Active
# 4         Active
# ..           ...                    ...            ...             ...
# 314  Passed/Dead                              New deal         On hold
# 315  Passed/Dead
# 316  Passed/Dead
# 317  Passed/Dead
# 318  Passed/Dead                                          Risk Profile
#
#             DealLeadId                              AdditionalDescription  \
# 0    Jeannie Blackwood  Electrical testing, maintenance, and commissio...
# 1           Andrew Mah  Provider of comprehensive, turnkey security so...
# 2           Kripa Shah  Provider of energy efficiency and demand manag...
# 3          Russ Barner  Specialty contractor serving the electric powe...
# 4    Matthew Kordonowy  Provider of remanufactured replacement parts t...
# ..                 ...                                                ...
# 314         Andrew Mah  Roll-up of dermatology practices / owned by LL...
# 315         Kripa Shah  Owner and operator of 45 Firebirds branded res...
# 316        Russ Barner  Producer and marketer of arts and crafts products
# 317  Matthew Kordonowy  Direct-to-consumer marketer of women's apparel...
# 318      Hannah Wilson  Largest independent clinical research site ser...
#
#                        File
# 0    all_verticals_deals_df
# 1    all_verticals_deals_df
# 2    all_verticals_deals_df
# 3    all_verticals_deals_df
# 4    all_verticals_deals_df
# ..                      ...
# 314  all_verticals_deals_df
# 315  all_verticals_deals_df
# 316  all_verticals_deals_df
# 317  all_verticals_deals_df
# 318  all_verticals_deals_df
#
# [319 rows x 14 columns]

# %%
#Check for each column in the transformed DataFrame is part of the original Company DataFrame
if not set(transform_deals_df.columns).issubset(deals_df.columns):
    raise ValueError(f"transform_deals_df has columns not in deals_df: {set(transform_deals_df.columns) - set(deals_df.columns)}")
else:
    print("All columns matched successfully.")
# Out:
# All columns matched successfully.

# %% [markdown]
# # Data Cleansing

# %%
transform_deals_df['Id'] = ['DT_{:03d}'.format(i) for i in range(1, len(transform_deals_df) + 1)]

# %%
transform_deals_df
# Out:
#      DealName                 CompanyId             DealDate       SourcingId  \
# 0                               Shermco  2018-02-02 00:00:00          Auction
# 1                        Kastle Systems  2018-02-02 00:00:00   Trusted Netwok
# 2                            CLEAResult  2018-02-02 00:00:00   Trusted Netwok
# 3                                   PLH  2018-02-02 00:00:00          Auction
# 4                        BBB Industries  2018-02-02 00:00:00          Auction
# ..        ...                       ...                  ...              ...
# 314               Schweiger Dermatology  2018-01-17 00:00:00  Trusted Network
# 315                           Firebirds  2017-12-01 00:00:00
# 316                               Pacon  2017-12-01 00:00:00
# 317                     Potpourri Group  2017-12-01 00:00:00
# 318  Red Hawk  Evolution Research Group  2018-01-26 00:00:00          Auction
#
#            InvestmentBankId   TransactionTypeId EstimateEquityInvestment  \
# 0           Harris Williams  Sponsor to Sponsor                    133.5
# 1                            Sponsor to Sponsor
# 2                            Sponsor to Sponsor
# 3                  Barclays  Sponsor to Sponsor                    340.0
# 4          Baird, Jefferies  Sponsor to Sponsor                    500.0
# ..                      ...                 ...                      ...
# 314                    N/A   Sponsor to Sponsor
# 315   North Point Advisors
# 316                  Baird
# 317  Lincoln International
# 318        Harris Williams   Sponsor to Sponsor
#
#         StatusId PortfolioCompanyStatus ActiveStagesId PassedRationale  \
# 0         Active
# 1         Active
# 2         Active
# 3         Active
# 4         Active
# ..           ...                    ...            ...             ...
# 314  Passed/Dead                              New deal         On hold
# 315  Passed/Dead
# 316  Passed/Dead
# 317  Passed/Dead
# 318  Passed/Dead                                          Risk Profile
#
#             DealLeadId                              AdditionalDescription  \
# 0    Jeannie Blackwood  Electrical testing, maintenance, and commissio...
# 1           Andrew Mah  Provider of comprehensive, turnkey security so...
# 2           Kripa Shah  Provider of energy efficiency and demand manag...
# 3          Russ Barner  Specialty contractor serving the electric powe...
# 4    Matthew Kordonowy  Provider of remanufactured replacement parts t...
# ..                 ...                                                ...
# 314         Andrew Mah  Roll-up of dermatology practices / owned by LL...
# 315         Kripa Shah  Owner and operator of 45 Firebirds branded res...
# 316        Russ Barner  Producer and marketer of arts and crafts products
# 317  Matthew Kordonowy  Direct-to-consumer marketer of women's apparel...
# 318      Hannah Wilson  Largest independent clinical research site ser...
#
#                        File      Id
# 0    all_verticals_deals_df  DT_001
# 1    all_verticals_deals_df  DT_002
# 2    all_verticals_deals_df  DT_003
# 3    all_verticals_deals_df  DT_004
# 4    all_verticals_deals_df  DT_005
# ..                      ...     ...
# 314  all_verticals_deals_df  DT_315
# 315  all_verticals_deals_df  DT_316
# 316  all_verticals_deals_df  DT_317
# 317  all_verticals_deals_df  DT_318
# 318  all_verticals_deals_df  DT_319
#
# [319 rows x 15 columns]

# %%
# Concatenate result DataFrames with company_df to bring all columns together
deal_transformed= pd.concat([
    deals_df,
    transform_deals_df
], ignore_index=True)

# %% [markdown]
# # Validate Contact Data Model

# %%
#Check for each column in the transformed DataFrame is part of the original Company DataFrame
if not set(deals_df.columns).issubset(deal_transformed.columns):
    raise ValueError(f"contact_df has columns not in contact_transformed: {set(deals_df.columns) - set(deal_transformed.columns)}")
else:
    print("All columns matched successfully.")
# Out:
# All columns matched successfully.

# %%
deal_transformed = deal_transformed.drop('File', axis=1)

# %%
# Fill NaN values with empty strings
deal_transformed = deal_transformed.fillna('')

# %%
# Trim all string values
deal_transformed = deal_transformed.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %%
deal_transformed
# Out:
#          Id  DealName                 CompanyId             DealDate  \
# 0    DT_001                             Shermco  2018-02-02 00:00:00
# 1    DT_002                      Kastle Systems  2018-02-02 00:00:00
# 2    DT_003                          CLEAResult  2018-02-02 00:00:00
# 3    DT_004                                 PLH  2018-02-02 00:00:00
# 4    DT_005                      BBB Industries  2018-02-02 00:00:00
# ..      ...       ...                       ...                  ...
# 314  DT_315               Schweiger Dermatology  2018-01-17 00:00:00
# 315  DT_316                           Firebirds  2017-12-01 00:00:00
# 316  DT_317                               Pacon  2017-12-01 00:00:00
# 317  DT_318                     Potpourri Group  2017-12-01 00:00:00
# 318  DT_319  Red Hawk  Evolution Research Group  2018-01-26 00:00:00
#
#           InvestmentBankId       SourcingId   TransactionTypeId  \
# 0          Harris Williams          Auction  Sponsor to Sponsor
# 1                            Trusted Netwok  Sponsor to Sponsor
# 2                            Trusted Netwok  Sponsor to Sponsor
# 3                 Barclays          Auction  Sponsor to Sponsor
# 4         Baird, Jefferies          Auction  Sponsor to Sponsor
# ..                     ...              ...                 ...
# 314                    N/A  Trusted Network  Sponsor to Sponsor
# 315   North Point Advisors
# 316                  Baird
# 317  Lincoln International
# 318        Harris Williams          Auction  Sponsor to Sponsor
#
#     EstimateEquityInvestment SaleDate SalePrice SaleType BuyingSponserId  \
# 0                      133.5
# 1
# 2
# 3                      340.0
# 4                      500.0
# ..                       ...      ...       ...      ...             ...
# 314
# 315
# 316
# 317
# 318
#
#     SellingSponserId     StatusId PortfolioCompanyStatus ActiveStagesId  \
# 0                          Active
# 1                          Active
# 2                          Active
# 3                          Active
# 4                          Active
# ..               ...          ...                    ...            ...
# 314                   Passed/Dead                              New deal
# 315                   Passed/Dead
# 316                   Passed/Dead
# 317                   Passed/Dead
# 318                   Passed/Dead
#
#     PassedRationale         DealLeadId  \
# 0                    Jeannie Blackwood
# 1                           Andrew Mah
# 2                           Kripa Shah
# 3                          Russ Barner
# 4                    Matthew Kordonowy
# ..              ...                ...
# 314         On hold         Andrew Mah
# 315                         Kripa Shah
# 316                        Russ Barner
# 317                  Matthew Kordonowy
# 318    Risk Profile      Hannah Wilson
#
#                                  AdditionalDescription CreatedAt CreatedBy  \
# 0    Electrical testing, maintenance, and commissio...
# 1    Provider of comprehensive, turnkey security so...
# 2    Provider of energy efficiency and demand manag...
# 3    Specialty contractor serving the electric powe...
# 4    Provider of remanufactured replacement parts t...
# ..                                                 ...       ...       ...
# 314  Roll-up of dermatology practices / owned by LL...
# 315  Owner and operator of 45 Firebirds branded res...
# 316  Producer and marketer of arts and crafts products
# 317  Direct-to-consumer marketer of women's apparel...
# 318  Largest independent clinical research site ser...
#
#     UpdatedAt UpdatedBy
# 0
# 1
# 2
# 3
# 4
# ..        ...       ...
# 314
# 315
# 316
# 317
# 318
#
# [319 rows x 23 columns]

# %% [markdown]
# # Export Companies Data

# %%
# %store deal_transformed
# Out:
# Stored 'deal_transformed' (DataFrame)
