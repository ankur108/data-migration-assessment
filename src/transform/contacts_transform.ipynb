# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Importind DataFrames

# %%
# %store -r all_verticals_deals_df
# %store -r contacts_df
# %store -r events_df

# %% [markdown]
# # Mapping to 'Contact' Target Data Model

# %%
# Define the Contacts columns
columns = [
    "Id",
    "ContactName",
    "CompanyId",
    "JobTitle",
    "Email",
    "PrimaryPhoneNumber",
    "SecondaryPhoneNumber",
    "Region",
    "VerticalId",
    "SubVerticalId",
    "Birthday",
    "CoveragePersonId",
    "PreferredContactMethodId",
    "AdditionalDescription",
    "CreatedAt",
    "CreatedBy",
    "UpdatedAt",
    "UpdatedBy",
    "File"
]

# Create an empty DataFrame with the columns
contact_df = pd.DataFrame(columns=columns)

# %%
# Populate the Contacts DataFrame with Contact Information
transform_contacts_df = pd.DataFrame()

transform_contacts_df['ContactName'] = contacts_df['Name']
transform_contacts_df['CompanyId'] = contacts_df['Firm']
transform_contacts_df['JobTitle'] = contacts_df['Title']
transform_contacts_df['Email'] = contacts_df['E-mail']
transform_contacts_df['PrimaryPhoneNumber'] = contacts_df['Phone']
transform_contacts_df['SecondaryPhoneNumber'] = contacts_df['Secondary Phone']
transform_contacts_df['Region'] = contacts_df['City']
transform_contacts_df['VerticalId'] = contacts_df['Group']
transform_contacts_df['SubVerticalId'] = contacts_df['Sub-Vertical']
transform_contacts_df['Birthday'] = contacts_df['Birthday']
transform_contacts_df['CoveragePersonId'] = contacts_df['Coverage Person']
transform_contacts_df['PreferredContactMethodId'] = contacts_df['Preferred Contact Method']
transform_contacts_df['File'] = "contacts"

# %%
# Populate the Contacts DataFrame with Contact Information
transform_events_df = pd.DataFrame()

transform_events_df['ContactName'] = events_df['Name']
transform_events_df['Email'] = events_df['E-mail']
transform_events_df['File'] = "events"

# %%
# Populate the Contacts DataFrame with Deal Vertical Information
transform_dealContact_df = pd.DataFrame()

transform_dealContact_df['ContactName'] = all_verticals_deals_df['Banker']
transform_contacts_df['CompanyId'] = all_verticals_deals_df['Invest. Bank']
transform_dealContact_df['Email'] = all_verticals_deals_df['Banker Email']
transform_dealContact_df['PrimaryPhoneNumber'] = all_verticals_deals_df['Banker Phone Number']
transform_dealContact_df['File'] = "all_deal_verticals"

# %%
# Concatenate all transformed DataFrames into a single DataFrame
all_contact_transformed_df = pd.concat([
    transform_contacts_df,
    transform_events_df,
    transform_dealContact_df
], ignore_index=True)

# %%
all_contact_transformed_df = all_contact_transformed_df[~(all_contact_transformed_df['ContactName'].isna() | (all_contact_transformed_df['ContactName'] == ''))]
all_contact_transformed_df = all_contact_transformed_df.reset_index(drop=True)

# %%
all_contact_transformed_df = all_contact_transformed_df.fillna('')

# %%
#Display the first few rows of the transformed DataFrame
all_contact_transformed_df
# Out:
#           ContactName         CompanyId           JobTitle  \
# 0    Robert Baltimore   Harris Williams  Managing Director
# 1         Brian Lucas                    Managing Director
# 2         Luke Semple                    Managing Director
# 3        Drew Spitzer          Barclays  Managing Director
# 4         Derek Lewis  Baird, Jefferies  Managing Director
# ..                ...               ...                ...
# 482      Paul Jevnick
# 483        Dan Grabos
# 484      Karen Martin
# 485     Richard Agabs
# 486       Geoff Smith
#
#                                 Email PrimaryPhoneNumber SecondaryPhoneNumber  \
# 0       BBaltimore@harriswilliams.com     (804) 648-0072
# 1           blucas@harriswilliams.com     (804) 648-0072
# 2          lsemple@harriswilliams.com     (804) 648-0072
# 3         aspitzer@harriswilliams.com     (804) 648-0072
# 4           dlewis@harriswilliams.com     (804) 648-0072
# ..                                ...                ...                  ...
# 482             Paul Jevnick@BMO .com       793-260-4783
# 483         Dan Grabos@JP Morgan .com       309-141-5134
# 484             Karen Martin@BMO .com       861-530-1192
# 485      Richard Agabs@Jefferies .com       434-955-4824
# 486  Geoff Smith@Harris Williams .com       233-303-7527
#
#            Region         VerticalId      SubVerticalId   Birthday  \
# 0    Richmond, VA  Business Services  Business Services  2/25/1966
# 1    Richmond, VA  Business Services  Business Services   9/3/1953
# 2    Richmond, VA  Business Services  Business Services  3/27/1962
# 3    Richmond, VA  Business Services  Business Services  4/28/1964
# 4    Richmond, VA  Business Services  Business Services  4/24/1971
# ..            ...                ...                ...        ...
# 482
# 483
# 484
# 485
# 486
#
#     CoveragePersonId PreferredContactMethodId                File
# 0      Hannah Jumper                    Email            contacts
# 1         Kripa Shah           Business Phone            contacts
# 2        Emily Royal               Cell Phone            contacts
# 3        Russ Barner           Business Phone            contacts
# 4        Daniel Ding               Cell Phone            contacts
# ..               ...                      ...                 ...
# 482                                            all_deal_verticals
# 483                                            all_deal_verticals
# 484                                            all_deal_verticals
# 485                                            all_deal_verticals
# 486                                            all_deal_verticals
#
# [487 rows x 13 columns]

# %%
#Check for each column in the transformed DataFrame is part of the original Company DataFrame
if not set(all_contact_transformed_df.columns).issubset(contact_df.columns):
    raise ValueError(f"all_contact_transformed_df has columns not in contact_df: {set(all_company_transformed_df.columns) - set(contact_df.columns)}")
else:
    print("All columns matched successfully.")
# Out:
# All columns matched successfully.

# %% [markdown]
# # Data Cleansing

# %%
all_contact_transformed_df['ContactName'].value_counts()
# Out:
# Andrew Verdasca     3
# Mark Pinsky         3
# Cristiano Lima      3
# Rex Green           3
# Mauro Souza         3
#                    ..
# Thomas Crowley      1
# Jack Rabun          1
# Rahul Singla        1
# Tommaso Zanobini    1
# Geoff Smith         1
# Name: ContactName, Length: 389, dtype: int64

# %%
# Group by 'all_company_transformed_df' and concatenate the results
all_contact_df = all_contact_transformed_df.groupby(['ContactName','Email']).agg(lambda x: ' '.join(x.astype(str))).reset_index()
all_contact_df
# Out:
#           ContactName                            Email        CompanyId  \
# 0         Aaron Engen              Aaron.Engen@BMO.com    William Blair
# 1        Aaron Kaplan   aaron.kaplan@credit-suisse.com   William Blair
# 2          Adam Dzaia               aczaia@rwbaird.com       JP Morgan
# 3         Adam Filkin    Adam Filkin@William Blair.com
# 4         Adam Nordin         adam.nordin@barclays.com   Morgan Stanley
# ..                ...                              ...              ...
# 391    Wes Harrington           Wes.Harrington@BMO.com    Direct to FIS
# 392     Whitney Horne             WHorne@jefferies.com  Goldman Sachs
# 393          Will Koo                 Will.Koo@BMO.com    Piper Jaffray
# 394  Xavier Loriferne  xavier.c.loriferne@jpmorgan.com   Houlihan Lokey
# 395    Zach Pfanstiel      zach.pfanstiel@jpmorgan.com  Harris Williams
#
#                                          JobTitle PrimaryPhoneNumber  \
# 0                  Managing Director, Global Head       403-515-1560
# 1                                       Director       312 750-2955
# 2                              Managing Director       414-298-7358
# 3                                                       808-881-5600
# 4    Managing Director, Head of Business Services       312-609-7223
# ..                                            ...                ...
# 391                                      Director       312-461-6531
# 392                           Managing Director
# 393                                      Director       212-702-1198
# 394                             Managing Director
# 395                            Executive Director
#
#     SecondaryPhoneNumber          Region           VerticalId  \
# 0                            Toronto, CA    Business Services
# 1                           Chicago, IL    Business Services
# 2                         Milwaukee, WI    Business Services
# 3
# 4                            Chicago, IL           Technology
# ..                   ...             ...                  ...
# 391                          Chicago, IL    Business Services
# 392                       New York, NY    Business Services
# 393                         New York, NY   Financial Services
# 394                         New York, NY   Financial Services
# 395                         New York, NY   Financial Services
#
#                             SubVerticalId     Birthday    CoveragePersonId  \
# 0                       Business Services    5/15/1957         Russ Barner
# 1    Industrial & Environmental Services     7/3/1970         Daniel Ding
# 2                      Business Services    5/18/1969   Jeannie Blackwood
# 3
# 4             Data & Information Services   10/28/1957          Kripa Shah
# ..                                    ...          ...                 ...
# 391   Industrial & Environmental Services     6/3/1966         Emily Royal
# 392                   Business Services    7/22/1972         Daniel Ding
# 393                             Insurance    1/11/1951       Hannah Jumper
# 394                         Product Group     4/9/1958         Daniel Ding
# 395                       Banks / Lending     3/9/1942         Daniel Ding
#
#     PreferredContactMethodId                    File
# 0                 Cell Phone                contacts
# 1            Business Phone          contacts events
# 2                     Email          contacts events
# 3                                 all_deal_verticals
# 4                      Email                contacts
# ..                       ...                     ...
# 391           Business Phone                contacts
# 392             Cell Phone    contacts events events
# 393               Cell Phone                contacts
# 394                    Email                contacts
# 395               Cell Phone                contacts
#
# [396 rows x 13 columns]

# %%
all_contact_df[['ContactName','Email']].value_counts()
# Out:
# ContactName       Email
# Aaron Engen       Aaron.Engen@BMO.com              1
# Melissa Wasser    Melissa.Wasser@ftpartners.com    1
# Mauro Souza       MSouza@jefferies.com             1
# Matthias Kirstol  Matthias.Kirstol@jpmorgan.com    1
# Matthew Stopnik   Matthew.Stopnik@rbbcm.com        1
#                                                   ..
# Dick Burke        rburke@jefferies.com             1
# Dhiren Shah       dhiren.shah@credit-suisse.com    1
# Devanshu Dhyani   devanshu.dhyani@gs.com           1
# Derek Lewis       dlewis@harriswilliams.com        1
# Zach Pfanstiel    zach.pfanstiel@jpmorgan.com      1
# Length: 396, dtype: int64

# %%
# Fill NaN values with empty strings
all_contact_df = all_contact_df.fillna('')

# %%
all_contact_df['Id'] = ['CT_{:03d}'.format(i) for i in range(1, len(all_contact_df) + 1)]

# %%
all_contact_df
# Out:
#           ContactName                            Email        CompanyId  \
# 0         Aaron Engen              Aaron.Engen@BMO.com    William Blair
# 1        Aaron Kaplan   aaron.kaplan@credit-suisse.com   William Blair
# 2          Adam Dzaia               aczaia@rwbaird.com       JP Morgan
# 3         Adam Filkin    Adam Filkin@William Blair.com
# 4         Adam Nordin         adam.nordin@barclays.com   Morgan Stanley
# ..                ...                              ...              ...
# 391    Wes Harrington           Wes.Harrington@BMO.com    Direct to FIS
# 392     Whitney Horne             WHorne@jefferies.com  Goldman Sachs
# 393          Will Koo                 Will.Koo@BMO.com    Piper Jaffray
# 394  Xavier Loriferne  xavier.c.loriferne@jpmorgan.com   Houlihan Lokey
# 395    Zach Pfanstiel      zach.pfanstiel@jpmorgan.com  Harris Williams
#
#                                          JobTitle PrimaryPhoneNumber  \
# 0                  Managing Director, Global Head       403-515-1560
# 1                                       Director       312 750-2955
# 2                              Managing Director       414-298-7358
# 3                                                       808-881-5600
# 4    Managing Director, Head of Business Services       312-609-7223
# ..                                            ...                ...
# 391                                      Director       312-461-6531
# 392                           Managing Director
# 393                                      Director       212-702-1198
# 394                             Managing Director
# 395                            Executive Director
#
#     SecondaryPhoneNumber          Region           VerticalId  \
# 0                            Toronto, CA    Business Services
# 1                           Chicago, IL    Business Services
# 2                         Milwaukee, WI    Business Services
# 3
# 4                            Chicago, IL           Technology
# ..                   ...             ...                  ...
# 391                          Chicago, IL    Business Services
# 392                       New York, NY    Business Services
# 393                         New York, NY   Financial Services
# 394                         New York, NY   Financial Services
# 395                         New York, NY   Financial Services
#
#                             SubVerticalId     Birthday    CoveragePersonId  \
# 0                       Business Services    5/15/1957         Russ Barner
# 1    Industrial & Environmental Services     7/3/1970         Daniel Ding
# 2                      Business Services    5/18/1969   Jeannie Blackwood
# 3
# 4             Data & Information Services   10/28/1957          Kripa Shah
# ..                                    ...          ...                 ...
# 391   Industrial & Environmental Services     6/3/1966         Emily Royal
# 392                   Business Services    7/22/1972         Daniel Ding
# 393                             Insurance    1/11/1951       Hannah Jumper
# 394                         Product Group     4/9/1958         Daniel Ding
# 395                       Banks / Lending     3/9/1942         Daniel Ding
#
#     PreferredContactMethodId                    File      Id
# 0                 Cell Phone                contacts  CT_001
# 1            Business Phone          contacts events  CT_002
# 2                     Email          contacts events  CT_003
# 3                                 all_deal_verticals  CT_004
# 4                      Email                contacts  CT_005
# ..                       ...                     ...     ...
# 391           Business Phone                contacts  CT_392
# 392             Cell Phone    contacts events events  CT_393
# 393               Cell Phone                contacts  CT_394
# 394                    Email                contacts  CT_395
# 395               Cell Phone                contacts  CT_396
#
# [396 rows x 14 columns]

# %%
# Concatenate result DataFrames with company_df to bring all columns together
contact_transformed= pd.concat([
    contact_df,
    all_contact_df
], ignore_index=True)

# %%
# Fill NaN values with empty strings
contact_transformed = contact_transformed.fillna('')

# %%
# Trim all string values
contact_transformed = contact_transformed.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %% [markdown]
# # Validate Contact Data Model

# %%
#Check for each column in the transformed DataFrame is part of the original Company DataFrame
if not set(contact_df.columns).issubset(contact_transformed.columns):
    raise ValueError(f"contact_df has columns not in contact_transformed: {set(contact_df.columns) - set(contact_transformed.columns)}")
else:
    print("All columns matched successfully.")
# Out:
# All columns matched successfully.

# %%
contact_transformed = contact_transformed.drop('File', axis=1)

# %%
contact_transformed
# Out:
#          Id       ContactName        CompanyId  \
# 0    CT_001       Aaron Engen    William Blair
# 1    CT_002      Aaron Kaplan    William Blair
# 2    CT_003        Adam Dzaia        JP Morgan
# 3    CT_004       Adam Filkin
# 4    CT_005       Adam Nordin   Morgan Stanley
# ..      ...               ...              ...
# 391  CT_392    Wes Harrington    Direct to FIS
# 392  CT_393     Whitney Horne    Goldman Sachs
# 393  CT_394          Will Koo    Piper Jaffray
# 394  CT_395  Xavier Loriferne   Houlihan Lokey
# 395  CT_396    Zach Pfanstiel  Harris Williams
#
#                                          JobTitle  \
# 0                  Managing Director, Global Head
# 1                                        Director
# 2                               Managing Director
# 3
# 4    Managing Director, Head of Business Services
# ..                                            ...
# 391                                      Director
# 392                             Managing Director
# 393                                      Director
# 394                             Managing Director
# 395                            Executive Director
#
#                                Email PrimaryPhoneNumber SecondaryPhoneNumber  \
# 0                Aaron.Engen@BMO.com       403-515-1560
# 1     aaron.kaplan@credit-suisse.com       312 750-2955
# 2                 aczaia@rwbaird.com       414-298-7358
# 3      Adam Filkin@William Blair.com       808-881-5600
# 4           adam.nordin@barclays.com       312-609-7223
# ..                               ...                ...                  ...
# 391           Wes.Harrington@BMO.com       312-461-6531
# 392             WHorne@jefferies.com
# 393                 Will.Koo@BMO.com       212-702-1198
# 394  xavier.c.loriferne@jpmorgan.com
# 395      zach.pfanstiel@jpmorgan.com
#
#             Region          VerticalId                        SubVerticalId  \
# 0      Toronto, CA   Business Services                    Business Services
# 1      Chicago, IL   Business Services  Industrial & Environmental Services
# 2    Milwaukee, WI   Business Services                    Business Services
# 3
# 4      Chicago, IL          Technology          Data & Information Services
# ..             ...                 ...                                  ...
# 391    Chicago, IL   Business Services  Industrial & Environmental Services
# 392   New York, NY   Business Services                    Business Services
# 393   New York, NY  Financial Services                            Insurance
# 394   New York, NY  Financial Services                        Product Group
# 395   New York, NY  Financial Services                      Banks / Lending
#
#        Birthday   CoveragePersonId PreferredContactMethodId  \
# 0     5/15/1957        Russ Barner               Cell Phone
# 1      7/3/1970        Daniel Ding           Business Phone
# 2     5/18/1969  Jeannie Blackwood                    Email
# 3
# 4    10/28/1957         Kripa Shah                    Email
# ..          ...                ...                      ...
# 391    6/3/1966        Emily Royal           Business Phone
# 392   7/22/1972        Daniel Ding               Cell Phone
# 393   1/11/1951      Hannah Jumper               Cell Phone
# 394    4/9/1958        Daniel Ding                    Email
# 395    3/9/1942        Daniel Ding               Cell Phone
#
#     AdditionalDescription CreatedAt CreatedBy UpdatedAt UpdatedBy
# 0
# 1
# 2
# 3
# 4
# ..                    ...       ...       ...       ...       ...
# 391
# 392
# 393
# 394
# 395
#
# [396 rows x 18 columns]

# %% [markdown]
# # Export Companies Data

# %%
# %store contact_transformed
# Out:
# Stored 'contact_transformed' (DataFrame)
